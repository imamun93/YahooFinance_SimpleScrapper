# %%
import pandas as pd
from bs4 import BeautifulSoup
import re
from selenium import webdriver
import chromedriver_binary
import string
import urllib.request

# %%
FB_Income= 'https://finance.yahoo.com/quote/FB/financials?p=FB'
FB_Balance= 'https://finance.yahoo.com/quote/FB/balance-sheet?p=FB'
FB_Statistic= 'https://finance.yahoo.com/quote/FB/key-statistics?p=FB'

# %% [markdown]
# ## Facebook Income

# %%
driver = webdriver.Safari()  #as long as you have webdriver installedl, you can replace Safari with any other browser. I could not get it to work with chrome or brave though

driver.get(FB_Income)
html = driver.execute_script('return document.body.innerHTML;')
soup = BeautifulSoup(html,'lxml') #click stop session after

# %% [markdown]
# If you don't want to use driver but the urllibrary instead:

# %%
url=urllib.request.urlopen(FB_Income)
print(str(url.getcode())) #200 means its working
# Out:
# 200

# %%
html= url.read()
html
# Out:
# b'<!DOCTYPE html><html id="atomic" class="NoJs featurephone" lang="en-US"><head prefix="og: http://ogp.me/ns#"><script>window.performance && window.performance.mark && window.performance.mark(\'PageStart\');</script><meta charset="utf-8"/><title>Facebook, Inc. (FB) Income Statement - Yahoo Finance</title><meta name="keywords" content="income statement,gross profit,revenue,operating expenses,operating income,net income,earning,earning per share"/><meta http-equiv="x-dns-prefetch-control" content="on"/><meta property="twitter:dnt" content="on"/><meta property="fb:app_id" content="90376669494"/><meta name="theme-color" content="#400090"/><meta name="viewport" content="width=device-width, initial-scale=1"/><meta name="description" lang="en-US" content="Get the detailed quarterly/annual income statement for Facebook, Inc. (FB). Find out the revenue, expenses and profit or loss over the last fiscal year."/><meta name="oath:guce:consent-host" content="guce.yahoo.com"/><meta name="msvalidate
# ...

# %%
soup = BeautifulSoup(html)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
#Does not work with urllib. Needs the driver method to work for this statement.
closingprice = [entry.text for entry in soup.find_all('span', {'class':'Trsdu(0.3s) Fw(b) Fz(36px) Mb(-4px) D(ib)'})]

closingprice
# Out:
# []

# %%
features= soup.find_all('div', class_='D(tbr)')

features
# Out:
# [<div class="D(tbr) C($primaryColor)" data-reactid="29"><div class="D(ib) Fw(b) Ta(start) Px(15px)--mv2 Px(10px) W(247px)--mv2 W(222px) Bxz(bb) Bdendw(1px) Bdstartw(1px) Bdbw(1px) Bdends(s) Bdstarts(s) Bdbs(s) Bdc($seperatorColor) Py(6px) Pos(st) Start(0) Bgc($lv2BgColor)" data-reactid="30"><span data-reactid="31">Breakdown</span><div class="W(3px) Pos(a) Start(100%) T(0) H(100%) Bg($pfColumnFakeShadowGradient) Pe(n) Pend(5px)" data-reactid="32"></div></div><div class="D(ib) Fw(b) Ta(end) Pstart(6px) Pend(4px) Py(6px) Bxz(bb) BdB Bdc($seperatorColor) Miw(100px) Miw(156px)--pnclg Tt(u) Bgc($lv1BgColor)" data-reactid="33"><span data-reactid="34">ttm</span></div><div class="D(ib) Fw(b) Ta(end) Pstart(6px) Pend(4px) Py(6px) Bxz(bb) BdB Bdc($seperatorColor) Miw(100px) Miw(156px)--pnclg" data-reactid="35"><span data-reactid="36">12/30/2019</span></div><div class="D(ib) Fw(b) Ta(end) Pstart(6px) Pend(4px) Py(6px) Bxz(bb) BdB Bdc($seperatorColor) Miw(100px) Miw(156px)--pnclg Bgc($lv1BgColor)
# ...

# %%
headers = []
temp_list = []
label_list = []
final = []
index = 0

#create headers
for item in features[0].find_all('div', class_='D(ib)'):
    headers.append(item.text)

#statement contents
while index <= len(features)-1:
    #filter for each line of the statement
    temp = features[index].find_all('div', class_='D(tbc)')
    for line in temp:
        #each item adding to a temporary list
        temp_list.append(line.text)
    #temp_list added to final list
    final.append(temp_list)
    #clear temp_list
    temp_list = []
    index+=1

# %%
final
# Out:
# [[],
#  ['Total Revenue',
#   '70,697,000',
#   '70,697,000',
#   '55,838,000',
#   '40,653,000',
#   '27,638,000'],
#  ['Cost of Revenue',
#   '12,770,000',
#   '12,770,000',
#   '9,355,000',
#   '5,454,000',
#   '3,789,000'],
#  ['Gross Profit',
#   '57,927,000',
#   '57,927,000',
#   '46,483,000',
#   '35,199,000',
#   '23,849,000'],
#  ['Operating Expenses', '', '', '', '', ''],
#  ['Research Development',
#   '13,600,000',
#   '13,600,000',
#   '10,273,000',
#   '7,754,000',
#   '5,919,000'],
#  ['Selling General and Administrative',
#   '20,341,000',
#   '20,341,000',
#   '11,297,000',
#   '7,242,000',
#   '5,503,000'],
#  ['Total Operating Expenses',
#   '33,941,000',
#   '33,941,000',
#   '21,570,000',
#   '14,996,000',
#   '11,422,000'],
#  ['Operating Income or Loss',
#   '23,986,000',
#   '23,986,000',
#   '24,913,000',
#   '20,203,000',
#   '12,427,000'],
#  ['Interest Expense', '20,000', '20,000', '9,000', '6,000', '10,000'],
#  ['Total Other Income/Expenses Net',
# ...

# %%
df = pd.DataFrame(final[1:])
df.columns = headers

#function to make all values numerical (or - for NaNs)
def convert_to_numeric(column):
    first_col = [i.replace(',','') for i in column]
    second_col = [i.replace('-','') for i in first_col]
    final_col = pd.to_numeric(second_col)   
    return final_col

for column in headers[1:]:    
    df[column] = convert_to_numeric(df[column])

# %%
fb_income = df.fillna('-')
fb_income
# Out:
#                                       Breakdown         ttm  12/30/2019  \
# 0                                 Total Revenue  7.0697e+07  7.0697e+07
# 1                               Cost of Revenue   1.277e+07   1.277e+07
# 2                                  Gross Profit  5.7927e+07  5.7927e+07
# 3                            Operating Expenses           -           -
# 4                          Research Development    1.36e+07    1.36e+07
# 5            Selling General and Administrative  2.0341e+07  2.0341e+07
# 6                      Total Operating Expenses  3.3941e+07  3.3941e+07
# 7                      Operating Income or Loss  2.3986e+07  2.3986e+07
# 8                              Interest Expense       20000       20000
# 9               Total Other Income/Expenses Net       78000       78000
# 10                            Income Before Tax  2.4812e+07  2.4812e+07
# 11                           Income Tax Expense   6.327e+06   6.327e+06
# ...

# %% [markdown]
# ## Facebook Balance

# %%
driver = webdriver.Safari()  #as long as you have webdriver installedl, you can replace Safari with any other browser. I could not get it to work with chrome or brave though

driver.get(FB_Balance)
html = driver.execute_script('return document.body.innerHTML;')
soup = BeautifulSoup(html,'lxml') #click stop session after

# %%
url=urllib.request.urlopen(FB_Balance)
print(str(url.getcode()))
# Out:
# 200

# %%
html= url.read()
soup = BeautifulSoup(html)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
features= soup.find_all('div', class_='D(tbr)')

# %%
headers = []
temp_list = []
label_list = []
final = []
index = 0

#create headers
for item in features[0].find_all('div', class_='D(ib)'):
    headers.append(item.text)

#statement contents
while index <= len(features)-1:
    #filter for each line of the statement
    temp = features[index].find_all('div', class_='D(tbc)')
    for line in temp:
        #each item adding to a temporary list
        temp_list.append(line.text)
    #temp_list added to final list
    final.append(temp_list)
    #clear temp_list
    temp_list = []
    index+=1

# %%
final
# Out:
# [[],
#  ['Assets', '', '', '', ''],
#  ['Current Assets', '', '', '', ''],
#  ['Cash', '', '', '', ''],
#  ['Cash And Cash Equivalents',
#   '19,079,000',
#   '10,019,000',
#   '8,079,000',
#   '8,903,000'],
#  ['Short Term Investments',
#   '35,776,000',
#   '31,095,000',
#   '33,632,000',
#   '20,546,000'],
#  ['Total Cash', '54,855,000', '41,114,000', '41,711,000', '29,449,000'],
#  ['Net Receivables', '9,518,000', '7,587,000', '5,832,000', '3,993,000'],
#  ['Total Current Assets',
#   '66,225,000',
#   '50,480,000',
#   '48,563,000',
#   '34,401,000'],
#  ['Non-current assets', '', '', '', ''],
#  ['Property, plant and equipment', '', '', '', ''],
#  ['Gross property, plant and equipment',
#   '55,446,000',
#   '31,573,000',
#   '18,337,000',
#   '11,803,000'],
#  ['Accumulated Depreciation',
#   '-10,663,000',
#   '-6,890,000',
#   '-4,616,000',
#   '-3,212,000'],
#  ['Net property, plant and equipment',
#   '44,783,000',
#   '24,683,000',
#   '13,721,000',
#   '8,591,000'],
# ...

# %%
balance= soup.find_all('div', class_='D(tbhg)')
balance
# Out:
# [<div class="D(tbhg)" data-reactid="28"><div class="D(tbr) C($primaryColor)" data-reactid="29"><div class="D(ib) Fw(b) Ta(start) Px(15px)--mv2 Px(10px) W(247px)--mv2 W(222px) Bxz(bb) Bdendw(1px) Bdstartw(1px) Bdbw(1px) Bdends(s) Bdstarts(s) Bdbs(s) Bdc($seperatorColor) Py(6px) Pos(st) Start(0) Bgc($lv2BgColor)" data-reactid="30"><span data-reactid="31">Breakdown</span><div class="W(3px) Pos(a) Start(100%) T(0) H(100%) Bg($pfColumnFakeShadowGradient) Pe(n) Pend(5px)" data-reactid="32"></div></div><div class="D(ib) Fw(b) Ta(end) Pstart(6px) Pend(4px) Py(6px) Bxz(bb) BdB Bdc($seperatorColor) Miw(100px) Miw(156px)--pnclg" data-reactid="33"><span data-reactid="34">12/30/2019</span></div><div class="D(ib) Fw(b) Ta(end) Pstart(6px) Pend(4px) Py(6px) Bxz(bb) BdB Bdc($seperatorColor) Miw(100px) Miw(156px)--pnclg Bgc($lv1BgColor)" data-reactid="35"><span data-reactid="36">12/30/2018</span></div><div class="D(ib) Fw(b) Ta(end) Pstart(6px) Pend(4px) Py(6px) Bxz(bb) BdB Bdc($seperatorColor) Miw(1
# ...

# %%
df = pd.DataFrame(final[1:])
df.columns = headers

# %%
df
# Out:
#                                      Breakdown   12/30/2019  12/30/2018  \
# 0                                       Assets
# 1                               Current Assets
# 2                                         Cash
# 3                    Cash And Cash Equivalents   19,079,000  10,019,000
# 4                       Short Term Investments   35,776,000  31,095,000
# 5                                   Total Cash   54,855,000  41,114,000
# 6                              Net Receivables    9,518,000   7,587,000
# 7                         Total Current Assets   66,225,000  50,480,000
# 8                           Non-current assets
# 9                Property, plant and equipment
# 10         Gross property, plant and equipment   55,446,000  31,573,000
# 11                    Accumulated Depreciation  -10,663,000  -6,890,000
# 12           Net property, plant and equipment   44,783,000  24,683,000
# 13                                    Goodwill   18,715,000  18,301,000
# ...

# %%
#function to make all values numerical (or - for NaNs)
def convert_to_numeric(column):
    first_col = [i.replace(',','') for i in column]
    second_col = [i.replace('-','') for i in first_col]
    final_col = pd.to_numeric(second_col)   
    return final_col

for column in headers[1:]:    
    df[column] = convert_to_numeric(df[column])

# %%
fb_balance= df.fillna('-')
fb_balance
# Out:
#                                      Breakdown   12/30/2019  12/30/2018  \
# 0                                       Assets            -           -
# 1                               Current Assets            -           -
# 2                                         Cash            -           -
# 3                    Cash And Cash Equivalents   1.9079e+07  1.0019e+07
# 4                       Short Term Investments   3.5776e+07  3.1095e+07
# 5                                   Total Cash   5.4855e+07  4.1114e+07
# 6                              Net Receivables    9.518e+06   7.587e+06
# 7                         Total Current Assets   6.6225e+07   5.048e+07
# 8                           Non-current assets            -           -
# 9                Property, plant and equipment            -           -
# 10         Gross property, plant and equipment   5.5446e+07  3.1573e+07
# 11                    Accumulated Depreciation   1.0663e+07    6.89e+06
# ...

# %% [markdown]
# ## Facebook Statistics

# %%
driver = webdriver.Safari()  #as long as you have webdriver installedl, you can replace Safari with any other browser. I could not get it to work with chrome or brave though

driver.get(FB_Statistic)
html = driver.execute_script('return document.body.innerHTML;')
soup = BeautifulSoup(html,'lxml')

# %%
url=urllib.request.urlopen(FB_Statistic)
print(str(url.getcode()))
# Out:
# 200

# %%
stats_table = soup.find_all("div", class_='Mstart(a) Mend(a)')
stats_table
# Out:
# [<div class="Mstart(a) Mend(a)" data-reactid="11"><div class="Fl(start) smartphone_W(100%) W(100%)" data-reactid="12"><h2 class="D(ib)" data-reactid="13"><span data-reactid="14">Valuation Measures</span></h2><div class="Fl(end)" data-reactid="15"><div class="Fz(s) Fw(500) D(ib) H(18px) C($actionBlueHover):h BdEnd Bdc($c-fuji-grey-e) Pend(15px) Mend(15px) C(black)" data-reactid="16"><span data-reactid="17">Annual</span></div><button class="P(0px) M(0px) C($c-fuji-blue-1-b) Bd(0px) O(n)" data-reactid="18"><div class="Fz(s) Fw(500) D(ib) H(18px) C($actionBlueHover):h BdEnd Bdc($c-fuji-grey-e) Pend(15px) Mend(15px) C($c-fuji-blue-1-b)" data-reactid="19"><span data-reactid="20">Quarterly</span></div></button><button class="P(0px) M(0px) C($c-fuji-blue-1-b) Bd(0px) O(n)" data-reactid="21"><div class="Fz(s) Fw(500) D(ib) H(18px) C($actionBlueHover):h C($c-fuji-blue-1-b)" data-reactid="22"><span data-reactid="23">Monthly</span></div></button></div><div class="Mb(10px) smartphone_Pend(0px) Pe
# ...

# %%
df = pd.read_html(str(stats_table),header=0)
df
# Out:
# [                    Unnamed: 0  Current 12/31/2019 12/31/2018 12/31/2017  \
#  0      Market Cap (intraday) 5  540.87B    585.37B    374.13B    512.76B
#  1           Enterprise Value 3  497.24B    542.24B    332.92B    474.47B
#  2                 Trailing P/E    29.51      32.89      19.74      34.20
#  3                Forward P/E 1    20.75      22.22      17.57      26.45
#  4  PEG Ratio (5 yr expected) 1     0.85       1.20       0.62       1.02
#  5            Price/Sales (ttm)     7.72       8.88       7.42      14.28
#  6             Price/Book (mrq)     5.35       6.23       4.66       7.20
#  7   Enterprise Value/Revenue 3     7.03       7.67       5.96      11.67
#  8    Enterprise Value/EBITDA 6    16.26      17.74      11.22      20.08
#
#    12/31/2016
#  0    331.59B
#  1    305.45B
#  2      44.42
#  3      22.42
#  4       0.52
#  5      13.49
#  6       6.15
#  7      11.05
#  8      20.54  ,           Beta (5Y Monthly)    1.08
# ...

# %%
stats= pd.concat(df, sort=False)

# %%
stats
# Out:
#                     Unnamed: 0  Current 12/31/2019 12/31/2018 12/31/2017  \
# 0      Market Cap (intraday) 5  540.87B    585.37B    374.13B    512.76B
# 1           Enterprise Value 3  497.24B    542.24B    332.92B    474.47B
# 2                 Trailing P/E    29.51      32.89      19.74      34.20
# 3                Forward P/E 1    20.75      22.22      17.57      26.45
# 4  PEG Ratio (5 yr expected) 1     0.85       1.20       0.62       1.02
# 5            Price/Sales (ttm)     7.72       8.88       7.42      14.28
# 6             Price/Book (mrq)     5.35       6.23       4.66       7.20
# 7   Enterprise Value/Revenue 3     7.03       7.67       5.96      11.67
# 8    Enterprise Value/EBITDA 6    16.26      17.74      11.22      20.08
# 0                          NaN      NaN        NaN        NaN        NaN
# 1                          NaN      NaN        NaN        NaN        NaN
# 2                          NaN      NaN        NaN        NaN        NaN
# ...
